# %%
from qiskit import QuantumCircuit, Aer
from qiskit.visualization import plot_histogram

# %%
a = 10
print(a)
a += 1
print(a)
# Out:
# 10
# 11

# %%
qc = QuantumCircuit(1, 1)  # qubit:1, cbit:1
qc.h(0)
qc.barrier()  # 点線をひく

# qc.measure([0], [0])
# qc.barrier()  # 点線をひく

qc.h(0)
qc.barrier()  # 点線をひく

qc.measure([0], [0])

qc.draw()

# %%
backend = Aer.get_backend("aer_simulator")
shots = 1024
results = backend.run(qc, shots=shots).result()
counts = results.get_counts()

plot_histogram(counts)

# %%
qc = QuantumCircuit(1, 1)  # qubit:1, cbit:1

qc.h(0)
qc.barrier()  # 点線をひく

qc.h(0)
qc.barrier()  # 点線をひく

qc.measure([0], [0])

qc.draw()

# %%
qc = QuantumCircuit(1, 1)  # qubit:1, cbit:1

qc.x(0)
qc.barrier()  # 点線をひく

qc.x(0)
qc.barrier()  # 点線をひく

qc.measure([0], [0])

qc.draw()

# %%
qc = QuantumCircuit(2, 2)  # qubit:2, cbit:2

qc.x(1)
qc.barrier()  # 点線をひく

qc.cx(0, 1)
qc.barrier()  # 点線をひく

qc.measure([0,1], [0,1])

qc.draw()

# %%
qc = QuantumCircuit(1, 1)  # qubit:1, cbit:1

qc.h(0)
qc.barrier()  # 点線をひく

qc.z(0)
qc.barrier()  # 点線をひく

qc.measure([0], [0])

qc.draw()
